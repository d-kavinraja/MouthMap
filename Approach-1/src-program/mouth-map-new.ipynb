p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwbn4p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwwh2n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lwwm2p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbij7s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbahzp.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwwq9s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lwbl8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/prbd1s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgwzzp.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwix1s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbiz2p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgifzn.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbaf5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwba7a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbas1s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbby3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgbr3a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgah2p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwwb1a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbaq5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgbh6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgbb2p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgii5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/swao5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbaa5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/brag1a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgaa7s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbwp8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwat5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/swwc5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgad8n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwad3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgaq7s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/priv4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srah4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbwc8n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwbg8n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgav5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbwm4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lrbzzp.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lriy1s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbbmzn.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srwvzn.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgac4p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lrae4p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lrak8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwwn7s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwbd7s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgbh5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgiz5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgay1s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgaz7s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srbo5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgat9s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgaq8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lrid8n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lriy2p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbwx3a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbad7s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgwl1s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgwj5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgig8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/swib3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbiz3a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/brwa5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwbn3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/brwa4p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbwk8n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lwws4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srin6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbbc7a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbaz7a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bras9a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbwp9a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbbn8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwbn5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bginzn.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgwp9s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lriy3a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bris2n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srwi4p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbaszn.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/braf8n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lwwf9a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/swwp3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgayzn.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbig4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgwe7s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/swbi6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgit6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lrwszp.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srbh8n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/prwj8n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/prac6n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwax5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbbc4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbal6n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgwazp.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgaf7a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwbk2p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lrbe8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwba5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwbkzn.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgin3a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgwdzn.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lrbl2p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbaa4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lwaz2p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbbk7a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbwb5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwbq6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgil5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbwu5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwwk4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgas5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbid3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbapzp.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgwi1a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgib8n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgak2n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgac3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgwm8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgbj3a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgwg2n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgas4p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srbu8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgwu8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwam9s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwax4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbby4p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgii2n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/swavzp.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbaq6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lrik5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbib9a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwidzp.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/prwx9a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lriezp.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgii3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbbk5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbit5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgbm3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbwm6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwwu1s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgan7a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgamzp.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/brif4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwim6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/swwc7a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pric2n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbat8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lwwm1s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbwj4p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgbjzn.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/prwq2n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwig1s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgwe8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lrws1a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srwi2n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lriq6n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bram5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbbn6n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgwj6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbaf2n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbaf4p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbbu2p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbie8n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lwazzn.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lrwz3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbay1a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbie9s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwwh5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/priv7a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbbz8n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgiq3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwba6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbwh8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwbd6n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgwo3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lriq7s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srah6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgwqzp.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgil6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbac1s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srau4p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgbc8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lwbz4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgaa9a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgwt3a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwis9s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwwy3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbiv1a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgas2n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbwh7s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgia5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lwbz5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwic8n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/brwt7a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srbb7a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lwwf7s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lrbe7s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbio6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbij6n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/prbq1a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/priv5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/prii6n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/swib2n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lwar9a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbaq4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgbu3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgbu5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lrae5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwwa9s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bwbhzp.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgaz8p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bris4p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbai4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbiqzn.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srbo4p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lrwl6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/swwi9s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lbwe4n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/brbg3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgin2p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lwbszn.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pwbd9a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbaz5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bris3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbii1s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/prwq5a.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgwr6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pbiu8n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srin5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sgwd2p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bgan6p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/bbwg2p.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/sbia1s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/pgaq6n.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/brwt5s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/lgiz3s.align
# /kaggle/input/mouth-map-comp/data/alignments/s1/srbh9s.align

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv3D, LSTM, Dense, Dropout, Bidirectional, MaxPool3D, BatchNormalization, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from glob import glob
import cv2

class LipReadingDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, data_path, alignment_path, batch_size=16, frame_length=75, 
                 image_height=46, image_width=140, video_paths=None, alignment_paths=None, 
                 fixed_vocabulary=None, **kwargs):
        super().__init__(**kwargs)
        self.data_path = data_path
        self.alignment_path = alignment_path
        self.batch_size = batch_size
        self.frame_length = frame_length
        self.image_height = image_height
        self.image_width = image_width

        # Use provided paths or generate from directory
        if video_paths is None:
            self.video_paths = sorted(glob(os.path.join(data_path, '*.mpg')))
        else:
            self.video_paths = video_paths
        
        if alignment_paths is None:
            self.alignment_paths = sorted(glob(os.path.join(alignment_path, '*.align')))
        else:
            self.alignment_paths = alignment_paths
        
        print(f"Found {len(self.video_paths)} video files and {len(self.alignment_paths)} alignment files")
        
        # Use fixed vocabulary if provided, otherwise create from data
        if fixed_vocabulary is not None:
            self.vocabulary = fixed_vocabulary
        else:
            self.vocabulary = self._create_word_vocabulary()
            
        self.char_to_num = tf.keras.layers.StringLookup(
            vocabulary=self.vocabulary, oov_token="")
        self.num_to_char = tf.keras.layers.StringLookup(
            vocabulary=self.vocabulary, oov_token="", invert=True)

    def _create_word_vocabulary(self):
        words = set()
        print(f"Processing alignment files from: {self.alignment_path}")
        
        for align_path in self.alignment_paths:
            try:
                with open(align_path, 'r') as f:
                    content = f.read().strip().split()
                    words.update([content[i] for i in range(2, len(content), 3)])
            except Exception as e:
                print(f"Error processing {align_path}: {str(e)}")
        
        words.discard('sil')
        vocabulary = sorted(list(words))
        
        if not vocabulary:
            print("No words found in alignment files. Using default vocabulary.")
            vocabulary = ['bin', 'blue', 'at', 'f', 'two', 'now']
        
        print(f"Vocabulary size: {len(vocabulary)}")
        return vocabulary

    def __len__(self):
        return max(1, len(self.video_paths) // self.batch_size)
    
    def _process_video(self, video_path):
        frames = []
        cap = cv2.VideoCapture(video_path)
        
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            mouth = gray[190:236, 80:220]
            mouth = cv2.resize(mouth, (self.image_width, self.image_height))
            frames.append(mouth)
        
        cap.release()
        
        frames = np.array(frames, dtype=np.float32)
        frames = (frames - frames.mean()) / (frames.std() + 1e-6)
        
        if len(frames) < self.frame_length:
            pad_length = self.frame_length - len(frames)
            frames = np.pad(frames, ((0, pad_length), (0, 0), (0, 0)), mode='constant')
        else:
            frames = frames[:self.frame_length]
        
        return frames
    
    def _process_alignment(self, alignment_path):
        with open(alignment_path, 'r') as f:
            content = f.read().strip().split()
        
        words = [content[i] for i in range(2, len(content), 3) if content[i] != 'sil']
        text = ' '.join(words)
        return self.char_to_num(tf.convert_to_tensor(text.split()))
    
    def __getitem__(self, idx):
        batch_videos = self.video_paths[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_alignments = self.alignment_paths[idx * self.batch_size:(idx + 1) * self.batch_size]
        
        X = np.zeros((len(batch_videos), self.frame_length, self.image_height, self.image_width, 1))
        Y = np.zeros((len(batch_videos), len(self.vocabulary)))
        
        for i, (video_path, align_path) in enumerate(zip(batch_videos, batch_alignments)):
            frames = self._process_video(video_path)
            X[i] = frames.reshape(self.frame_length, self.image_height, self.image_width, 1)
            
            labels = self._process_alignment(align_path)
            Y[i] = tf.reduce_max(tf.one_hot(labels, len(self.vocabulary)), axis=0)
        
        return X, Y

def build_model(frame_length, image_height, image_width, vocabulary_size):
    model = Sequential([
        tf.keras.Input(shape=(frame_length, image_height, image_width, 1)), 
        Conv3D(64, kernel_size=(3, 3, 3), activation='relu'),
        MaxPool3D(pool_size=(1, 2, 2)),
        BatchNormalization(),
        
        Conv3D(128, kernel_size=(3, 3, 3), activation='relu'),
        MaxPool3D(pool_size=(1, 2, 2)),
        BatchNormalization(),
        
        Conv3D(256, kernel_size=(3, 3, 3), activation='relu'),
        MaxPool3D(pool_size=(1, 2, 2)),
        BatchNormalization(),
        
        Reshape((-1, 256)),
        
        Bidirectional(LSTM(128, return_sequences=True)),
        Dropout(0.5),
        
        Bidirectional(LSTM(64)),
        Dropout(0.5),
        
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(vocabulary_size, activation='softmax')
    ])
    
    return model

def train_and_save_main_model(data_dir, alignment_dir, batch_size=16):
    print("Starting training for sentence-level prediction...")
    
    model_dir = "models_main"
    os.makedirs(model_dir, exist_ok=True)
    
    # Create full data generator to get consistent vocabulary
    full_data_generator = LipReadingDataGenerator(data_dir, alignment_dir, batch_size=batch_size)
    full_vocabulary = full_data_generator.vocabulary
    
    # Split video paths into two halves
    total_videos = len(full_data_generator.video_paths)
    mid_point = total_videos // 2
    
    # First half training
    first_half_generator = LipReadingDataGenerator(
        data_path=data_dir, 
        alignment_path=alignment_dir, 
        batch_size=batch_size,
        video_paths=full_data_generator.video_paths[:mid_point],
        alignment_paths=full_data_generator.alignment_paths[:mid_point],
        fixed_vocabulary=full_vocabulary
    )
    
    # Build and compile the model
    model = build_model(
        frame_length=75,
        image_height=46,
        image_width=140,
        vocabulary_size=len(full_vocabulary)
    )
    
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    # Callbacks for first half
    first_half_callbacks = [
        ModelCheckpoint(
            os.path.join(model_dir, 'lip_reading_first_half_best.keras'),
            save_best_only=True,
            monitor='accuracy'
        ),
        EarlyStopping(
            monitor='loss',
            patience=5,
            restore_best_weights=True
        )
    ]

    # Train on first half
    print("Training on first half of the dataset...")
    model.fit(
        first_half_generator,
        epochs=10,
        callbacks=first_half_callbacks
    )
    
    # Second half training
    second_half_generator = LipReadingDataGenerator(
        data_path=data_dir, 
        alignment_path=alignment_dir, 
        batch_size=batch_size,
        video_paths=full_data_generator.video_paths[mid_point:],
        alignment_paths=full_data_generator.alignment_paths[mid_point:],
        fixed_vocabulary=full_vocabulary
    )
    
    # Callbacks for second half
    second_half_callbacks = [
        ModelCheckpoint(
            os.path.join(model_dir, 'lip_reading_full_dataset_best.keras'),
            save_best_only=True,
            monitor='accuracy'
        ),
        EarlyStopping(
            monitor='loss',
            patience=5,
            restore_best_weights=True
        )
    ]

    # Train on second half
    print("Training on second half of the dataset...")
    model.fit(
        second_half_generator,
        epochs=10,
        callbacks=second_half_callbacks
    )

    # Save final model
    final_model_path = os.path.join(model_dir, 'lip_reading_full_model.h5')
    model.save(final_model_path)
    print(f"Final model saved: {final_model_path}")

    # Save vocabulary
    vocab_path = os.path.join(model_dir, 'vocabulary_main.txt')
    with open(vocab_path, 'w') as f:
        f.write('\n'.join(full_vocabulary))
    print(f"Vocabulary saved: {vocab_path}")

if __name__ == "__main__":
    data_dir = r"/kaggle/input/mouth-map-comp/data/s1"
    alignment_dir = r"/kaggle/input/mouth-map-comp/data/alignments/s1"
    
    print("Training main model...")
    train_and_save_main_model(data_dir, alignment_dir)
# Out:
# Training main model...
# Starting training for sentence-level prediction...
# Found 1000 video files and 1000 alignment files
# Processing alignment files from: /kaggle/input/mouth-map-comp/data/alignments/s1
# Vocabulary size: 52
# Found 500 video files and 500 alignment files
# Training on first half of the dataset...
# Epoch 1/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.0294 - loss: 23.3035
# Epoch 2/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.1069 - loss: 22.7980
# Epoch 3/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.1268 - loss: 22.9664
# Epoch 4/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.0864 - loss: 24.5097
# Epoch 5/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.1376 - loss: 27.4138
# Epoch 6/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.0840 - loss: 32.5829
# Epoch 7/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.0678 - loss: 35.8482
# Found 500 video files and 500 alignment files
# Training on second half of the dataset...
# Epoch 1/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.0757 - loss: 24.9081
# Epoch 2/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.0683 - loss: 24.6331
# Epoch 3/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.0848 - loss: 25.0249
# Epoch 4/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.0681 - loss: 26.2500
# Epoch 5/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.0453 - loss: 30.4885
# Epoch 6/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.0344 - loss: 36.2953
# Epoch 7/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.0336 - loss: 42.1963
# Final model saved: models_main/lip_reading_full_model.h5
# Vocabulary saved: models_main/vocabulary_main.txt
